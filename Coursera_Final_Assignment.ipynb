# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tanmay Nayyar**
#
# Student

# %% [markdown]
# _I am interested in Data Science because I believe it can hep us understand thw world around us better, and create and build the technologies of the future_

# %% [markdown]
# ### The below should print 'Hello World'

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# > True failure is in not getting back up when you fall
# >
#  - Socrates
#  - Plato
#
# <hr>
